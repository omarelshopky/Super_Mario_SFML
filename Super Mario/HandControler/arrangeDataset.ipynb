# %%
import cv2
import os
import time
import uuid

# %%
IMAGE_PATH = 'Tensorflow/workspace/images/collectedimages'

# %%
labels = ['right', 'left', 'standstill', 'jump', 'down', 'fire']
number_imgs = 16

# %%
for label in labels:
    # !mkdir {'Tensorflow\workspace\images\collectedimages\\' + label}
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        ret, frame = cap.read()
        imagename = os.path.join(IMAGE_PATH, label, label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imagename, frame)
        cv2.imshow('frame', frame)
        time.sleep(2)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
# Out:
# A subdirectory or file Tensorflow\workspace\images\collectedimages\right already exists.
# Collecting images for right
# Collecting images for left
# Collecting images for standstill
# Collecting images for jump
# Collecting images for down
# Collecting images for fire
